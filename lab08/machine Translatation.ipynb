# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/NLP/lab08/machine-translation-main/NMT
# Out:
# /content/drive/MyDrive/NLP/lab08/machine-translation-main/NMT

# %%
# !python main.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/NLP/lab08/machine-translation-main/NMT/main.py", line 10, in <module>
#     from decoder import *
#   File "/content/drive/MyDrive/NLP/lab08/machine-translation-main/NMT/decoder.py", line 4, in <module>
#     from multiheaded_attention import *
#   File "/content/drive/MyDrive/NLP/lab08/machine-translation-main/NMT/multiheaded_attention.py", line 11, in <module>
#     from icecream import ic
# ModuleNotFoundError: No module named 'icecream'

# %%
# !pip install icecream

# %%
# !python main.py
# Out:
# 2.2.1+cu121
# Multihead...
# Position...
# PositionEncoding...
# Build Encoder-Decoder
# Init Params...
# EncoderDecoder(
#   (encoder): Encoder(
#     (layers): ModuleList(
#       (0-5): 6 x EncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linears): ModuleList(
#             (0-3): 4 x Linear(in_features=512, out_features=512, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (sublayer): ModuleList(
#           (0-1): 2 x SublayerConnection(
#             (norm): LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (norm): LayerNorm()
#   )
#   (decoder): Decoder(
# ...
